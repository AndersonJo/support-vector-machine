# %% [markdown]
# # Example

# %%
# %pylab inline
import numpy as np
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
def f(x):
    return np.exp(x + x**2)

def f_d(x):
    return (2*x + 1) * np.exp(x + x**2)

def f_d2(x):
     return (4*x**2 + 4*x + 3) * np.exp(x + x**2)

def quadratic_approximate(x):
    return f(0) + f_d(0) * x + f_d2(0)/2 * x**2
    
x = np.linspace(-1.5, 0.5, 1000)
y = quadratic_approximate(x)

plt.plot(x, f(x), label='original')
plt.plot(x, quadratic_approximate(x), label='quadratic approximation')
plt.grid()
plt.legend()
